# %% [markdown]
# <a href="https://colab.research.google.com/github/shu-nya/Corona-Virus-Tweet-Sentiment-analysis/blob/master/Coronavirus_Tweet_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><u> Project Title : Sentiment Analysis : Predicting sentiment of COVID-19 tweets</u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### This challenge asks you to build a classification model to predict the sentiment of COVID-19 tweets.The tweets have been pulled from Twitter and manual tagging has been done then.
#
# ### The names and usernames have been given codes to avoid any privacy concerns.
#
# ### You are given the following information:
# 1. Location
# 2. Tweet At
# 3. Original Tweet
# 4. Label

# %% [markdown]
# ##Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##Importing the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Project datasets/Coronavirus Tweets.csv', encoding = 'latin-1')

# %% [markdown]
# ##Understanding the data

# %%
df.head()
# Out:
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
# 3      3802       48754        NaN  16-03-2020
# 4      3803       48755        NaN  16-03-2020
#
#                                        OriginalTweet           Sentiment
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...             Neutral
# 1  advice Talk to your neighbours family to excha...            Positive
# 2  Coronavirus Australia: Woolworths to give elde...            Positive
# 3  My food stock is not the only one which is emp...            Positive
# 4  Me, ready to go at supermarket during the #COV...  Extremely Negative

# %%
df.shape
# Out:
# (41157, 6)

# %%
df.columns
# Out:
# Index(['UserName', 'ScreenName', 'Location', 'TweetAt', 'OriginalTweet',
#        'Sentiment'],
#       dtype='object')

# %%
df.describe(include = 'all')
# Out:
#             UserName    ScreenName Location     TweetAt  \
# count   41157.000000  41157.000000    32567       41157
# unique           NaN           NaN    12220          30
# top              NaN           NaN   London  20-03-2020
# freq             NaN           NaN      540        3448
# mean    24377.000000  69329.000000      NaN         NaN
# std     11881.146851  11881.146851      NaN         NaN
# min      3799.000000  48751.000000      NaN         NaN
# 25%     14088.000000  59040.000000      NaN         NaN
# 50%     24377.000000  69329.000000      NaN         NaN
# 75%     34666.000000  79618.000000      NaN         NaN
# max     44955.000000  89907.000000      NaN         NaN
#
#                                             OriginalTweet Sentiment
# count                                               41157     41157
# unique                                              41157         5
# top     @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...  Positive
# freq                                                    1     11422
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41157 entries, 0 to 41156
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       41157 non-null  int64
#  1   ScreenName     41157 non-null  int64
#  2   Location       32567 non-null  object
#  3   TweetAt        41157 non-null  object
#  4   OriginalTweet  41157 non-null  object
#  5   Sentiment      41157 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# ##Analyse the features.

# %%
# TweetAt

df.TweetAt.value_counts()
# Out:
# 20-03-2020    3448
# 19-03-2020    3215
# 25-03-2020    2979
# 18-03-2020    2742
# 21-03-2020    2653
# 22-03-2020    2114
# 23-03-2020    2062
# 17-03-2020    1977
# 08-04-2020    1881
# 07-04-2020    1843
# 06-04-2020    1742
# 24-03-2020    1480
# 09-04-2020    1471
# 13-04-2020    1428
# 26-03-2020    1277
# 05-04-2020    1131
# 10-04-2020    1005
# 02-04-2020     954
# 11-04-2020     909
# 03-04-2020     810
# 12-04-2020     803
# 04-04-2020     767
# 16-03-2020     656
# 01-04-2020     630
# 27-03-2020     345
# 31-03-2020     316
# 14-04-2020     284
# 29-03-2020     125
# 30-03-2020      87
# 28-03-2020      23
# Name: TweetAt, dtype: int64

# %% [markdown]
# ##Observations:
#
# 1. All the tweets have come only from March and April of 2020.

# %%
# Location

df['Location'].value_counts()
# Out:
# London                          540
# United States                   528
# London, England                 520
# New York, NY                    395
# Washington, DC                  373
#                                ...
# Staffordshire Moorlands           1
# Kithchener ON                     1
# Tulsa, Ok                         1
# Watford, South Oxhey, Bushey      1
# i love you so much || he/him      1
# Name: Location, Length: 12220, dtype: int64

# %% [markdown]
# ##Observations:
#
# 1. There are 12220 unique locations from where the tweets have come.

# %%
# Sentiment

df['Sentiment'].value_counts()
# Out:
# Positive              11422
# Negative               9917
# Neutral                7713
# Extremely Positive     6624
# Extremely Negative     5481
# Name: Sentiment, dtype: int64

# %% [markdown]
# ##Observations:
#
# 1. There are 5 unique sentiment types in the dataset.

# %% [markdown]
# ##Digging deeper into tweet and sentiment.

# %%
df[df['Sentiment']=='Extremely Negative']
# Out:
#        UserName  ScreenName              Location     TweetAt  \
# 4          3803       48755                   NaN  16-03-2020
# 20         3819       48771  southampton soxx xxx  16-03-2020
# 27         3826       48778   Everywhere You Are!  16-03-2020
# 29         3828       48780        Someplace, USA  16-03-2020
# 42         3841       48793               Houston  16-03-2020
# ...         ...         ...                   ...         ...
# 41115     44914       89866                   NaN  14-04-2020
# 41128     44927       89879  Melbourne, Australia  14-04-2020
# 41130     44929       89881                   NaN  14-04-2020
# 41133     44932       89884               Austria  14-04-2020
# 41153     44952       89904                   NaN  14-04-2020
#
#                                            OriginalTweet           Sentiment
# 4      Me, ready to go at supermarket during the #COV...  Extremely Negative
# 20     with 100  nations inficted with  covid  19  th...  Extremely Negative
# 27     This morning I tested positive for Covid 19. I...  Extremely Negative
# 29     @7SealsOfTheEnd Soon with dwindling supplies u...  Extremely Negative
# 42     CHECK VIDEO ?? https://t.co/1ksn9Brl02 ??No fo...  Extremely Negative
# ...                                                  ...                 ...
# 41115  Food Banks are not equipped for a 30% unemploy...  Extremely Negative
# 41128  The COVID-19 pandemic and global oil price war...  Extremely Negative
# 41130  Squeo works in the meat department of a Kroger...  Extremely Negative
# 41133  A Singaporean politician who slammed a woman s...  Extremely Negative
# 41153  Response to complaint not provided citing COVI...  Extremely Negative
#
# [5481 rows x 6 columns]

# %% [markdown]
# ##Observations:
#
# 1. 5481 tweets have sentiment 'Extremely Negative'.

# %%
df[df['Sentiment']=='Extremely Negative'].loc[20,'OriginalTweet']
# Out:
# 'with 100  nations inficted with  covid  19  the world must  not  play fair with china  100 goverments must demand  china  adopts new guilde  lines on food safty  the  chinese  goverment  is guilty of  being  irosponcible   with life  on a global scale'

# %%
df[df['Sentiment']=='Extremely Negative'].loc[41153,'OriginalTweet']
# Out:
# 'Response to complaint not provided citing COVID-19 related delays. Yet prompt in rejecting policy before consumer TAT is over. Way to go ?'

# %%
df[df['Sentiment']=='Negative']
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 9          3808       48760              BHAVNAGAR,GUJRAT  16-03-2020
# 24         3823       48775              Downstage centre  16-03-2020
# 26         3825       48777                Ketchum, Idaho  16-03-2020
# 28         3827       48779                  New York, NY  16-03-2020
# 30         3829       48781                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41127     44926       89878                           NaN  14-04-2020
# 41131     44930       89882                  Accra, Ghana  14-04-2020
# 41147     44946       89898                  Brooklyn, NY  14-04-2020
# 41149     44948       89900              Toronto, Ontario  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet Sentiment
# 9      For corona prevention,we should stop to buy th...  Negative
# 24     @10DowningStreet @grantshapps what is being do...  Negative
# 26     In preparation for higher demand and a potenti...  Negative
# 28     Do you see malicious price increases in NYC? T...  Negative
# 30     There Is of in the Country  The more empty she...  Negative
# ...                                                  ...       ...
# 41127  Today at the grocery store I saw someone getti...  Negative
# 41131  In every human affliction there are  gainers a...  Negative
# 41147  YÂall really shitting that much more at home?...  Negative
# 41149  Still shocked by the number of #Toronto superm...  Negative
# 41156  @TartiiCat Well new/used Rift S are going for ...  Negative
#
# [9917 rows x 6 columns]

# %% [markdown]
# ##Observations:
#
# 1. 9917 tweets have sentiment 'Negative'.

# %%
df[df['Sentiment']=='Negative'].loc[41149,'OriginalTweet']
# Out:
# 'Still shocked by the number of #Toronto supermarket employees working without some sort of mask. We all know by now, employees can be asymptomatic while spreading #coronavirus .'

# %%
df[df['Sentiment']=='Neutral']
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 7          3806       48758                       Austria  16-03-2020
# 10         3809       48761                Makati, Manila  16-03-2020
# 16         3815       48767                  Saudi Arabia  16-03-2020
# 17         3816       48768               Ontario, Canada  16-03-2020
# ...         ...         ...                           ...         ...
# 41141     44940       89892                         India  14-04-2020
# 41143     44942       89894              In burning hell.  14-04-2020
# 41144     44943       89895                           NaN  14-04-2020
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
#
#                                            OriginalTweet Sentiment
# 0      @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...   Neutral
# 7      Was at the supermarket today. Didn't buy toile...   Neutral
# 10     All month there hasn't been crowding in the su...   Neutral
# 16     ????? ????? ????? ????? ??\r\r\n?????? ????? ?...   Neutral
# 17     @eyeonthearctic 16MAR20 Russia consumer survei...   Neutral
# ...                                                  ...       ...
# 41141  #Coronavirus ?? ????? ??? ????? ?? ??? ???????...   Neutral
# 41143  https://t.co/8s4vKvcO1r #5gtowers?? #EcuadorUn...   Neutral
# 41144  @_Sunrise_SV @Gamzap @NPR What does not having...   Neutral
# 41152  Airline pilots offering to stock supermarket s...   Neutral
# 41155  Is it wrong that the smell of hand sanitizer i...   Neutral
#
# [7713 rows x 6 columns]

# %% [markdown]
# ##Observations:
#
# 1. 7713 tweets have sentiment 'Neutral'.

# %%
df[df['Sentiment']=='Neutral'].loc[17,'OriginalTweet']
# Out:
# '@eyeonthearctic 16MAR20 Russia consumer surveillance watchdog reported case in high Arctic where a man who traveled to Iran has COVID-19 and 101 are "observed"\r\r\nhttps://t.co/4WnrrK9oKC https://t.co/ld05k5Eyns'

# %%
df[df['Sentiment']=='Neutral'].loc[16,'OriginalTweet']
# Out:
# '????? ????? ????? ????? ??\r\r\n?????? ????? ??????? ????????? ?\r\r\n#????_???? ????? ???? ?????? ? #????????? ?????? ?? 13 ???? ?? ?? ???? ?????? ?? ??\r\r\n#???_???????? ????? ??? ???? ? https://t.co/51bL8P6vZh'

# %%
df[df['Sentiment']=='Positive']
# Out:
#        UserName  ScreenName                   Location     TweetAt  \
# 1          3800       48752                         UK  16-03-2020
# 2          3801       48753                  Vagabonds  16-03-2020
# 3          3802       48754                        NaN  16-03-2020
# 5          3804       48756  ÃT: 36.319708,-82.363649  16-03-2020
# 6          3805       48757       35.926541,-78.753267  16-03-2020
# ...         ...         ...                        ...         ...
# 41140     44939       89891                   Pakistan  14-04-2020
# 41145     44944       89896              Manhattan, NY  14-04-2020
# 41146     44945       89897             Gurgaon, India  14-04-2020
# 41150     44949       89901                       OHIO  14-04-2020
# 41154     44953       89905                        NaN  14-04-2020
#
#                                            OriginalTweet Sentiment
# 1      advice Talk to your neighbours family to excha...  Positive
# 2      Coronavirus Australia: Woolworths to give elde...  Positive
# 3      My food stock is not the only one which is emp...  Positive
# 5      As news of the regionÂs first confirmed COVID...  Positive
# 6      Cashier at grocery store was sharing his insig...  Positive
# ...                                                  ...       ...
# 41140  Good News! \r\r\nWe'll Soon Announce Our High ...  Positive
# 41145  How exactly are we going to re-open New York C...  Positive
# 41146  #Gold prices rose to a more than 7-year high t...  Positive
# 41150  I never that weÂd be in a situation &amp; wor...  Positive
# 41154  You know itÂs getting tough when @KameronWild...  Positive
#
# [11422 rows x 6 columns]

# %% [markdown]
# ##Observations:
#
# 1. 11422 tweets have sentiment 'Positive'.

# %%
df[df['Sentiment']=='Positive'].loc[1,'OriginalTweet']
# Out:
# 'advice Talk to your neighbours family to exchange phone numbers create contact list with phone numbers of neighbours schools employer chemist GP set up online shopping accounts if poss adequate supplies of regular meds but not over order'

# %%
df[df['Sentiment']=='Positive'].loc[6,'OriginalTweet']
# Out:
# 'Cashier at grocery store was sharing his insights on #Covid_19 To prove his credibility he commented "I\'m in Civics class so I know what I\'m talking about". https://t.co/ieFDNeHgDO'

# %%
df[df['Sentiment']=='Extremely Positive']
# Out:
#        UserName  ScreenName                   Location     TweetAt  \
# 11         3810       48762  Pitt Meadows, BC, Canada   16-03-2020
# 12         3811       48763                 Horningsea  16-03-2020
# 18         3817       48769              North America  16-03-2020
# 22         3821       48773                        NaN  16-03-2020
# 23         3822       48774                        NaN  16-03-2020
# ...         ...         ...                        ...         ...
# 41137     44936       89888                   LES, NYC  14-04-2020
# 41138     44937       89889            Los Angeles, CA  14-04-2020
# 41142     44941       89893           Juba south sudan  14-04-2020
# 41148     44947       89899                        NaN  14-04-2020
# 41151     44950       89902                        NaN  14-04-2020
#
#                                            OriginalTweet           Sentiment
# 11     Due to the Covid-19 situation, we have increas...  Extremely Positive
# 12     #horningsea is a caring community. LetÂs ALL ...  Extremely Positive
# 18     Amazon Glitch Stymies Whole Foods, Fresh Groce...  Extremely Positive
# 22     We have AMAZING CHEAP DEALS! FOR THE #COVID201...  Extremely Positive
# 23     We have AMAZING CHEAP DEALS! FOR THE #COVID201...  Extremely Positive
# ...                                                  ...                 ...
# 41137  Distilleries have switched portions of their p...  Extremely Positive
# 41138  HMU FOR PRICES!! Got great deals going right n...  Extremely Positive
# 41142  @MajangChien @MTNSSD @MTNSSD is worst than COV...  Extremely Positive
# 41148  UV light Sterilizer Sanitizer for your mask an...  Extremely Positive
# 41151  @MrSilverScott you are definitely my man. I fe...  Extremely Positive
#
# [6624 rows x 6 columns]

# %% [markdown]
# ##Observations:
#
# 1. 6624 tweets have sentiment 'Extremely Positive'.

# %%
df[df['Sentiment']=='Extremely Positive'].loc[11,'OriginalTweet']
# Out:
# 'Due to the Covid-19 situation, we have increased demand for all food products. \r\r\n\r\r\nThe wait time may be longer for all online orders, particularly beef share and freezer packs. \r\r\n\r\r\nWe thank you for your patience during this time.'

# %%
df[df['Sentiment']=='Extremely Positive'].loc[22,'OriginalTweet']
# Out:
# 'We have AMAZING CHEAP DEALS! FOR THE #COVID2019 going on to help you???\r\r\n#Trials\r\r\n#Monthly\r\r\n#Yearly \r\r\nAnd Resonable #Prices / #Subscriptions\r\r\nJust DM US! #bestiptv #iptv #Service #Iptv #iptvdeals #Cheap #ipTV #Football #HD #Movies #Adult #Cinema #hotmovies #iptvnew #iptv2020 #Adult'

# %%
pd.isnull(df["Sentiment"])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41152    False
# 41153    False
# 41154    False
# 41155    False
# 41156    False
# Name: Sentiment, Length: 41157, dtype: bool

# %% [markdown]
# ##Observations:
#
# 1. Feature Sentiment has no null element.

# %% [markdown]
# ##Sentiments Countplot

# %%
sns.set(font_scale=1.1)
sns.catplot("Sentiment", data=df, kind="count", height=8)

# %% [markdown]
# ##Looking For Null Values

# %%
missing_values = pd.DataFrame()
missing_values['column'] = df.columns

missing_values['percent'] = [round(100* df[col].isnull().sum() / len(df), 2) for col in df.columns]
missing_values = missing_values.sort_values('percent')
missing_values = missing_values[missing_values['percent']>0]

# %%
plt.figure(figsize=(15, 5))
sns.set(style='whitegrid', color_codes=True)
splot=sns.barplot(x='column', y='percent', data=missing_values, color='brown')
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center',
                   va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.xlabel("Column_Name", size=14, weight="bold")
plt.ylabel("Percentage", size=14, weight="bold")
plt.title("Percentage of missing values in column",fontweight="bold",size=17)
plt.show()

# %% [markdown]
# ##Observations:
#
# 1. Only one feature 'Location' has null element.
#
# 2. 20.87% elements in 'Location' are null.

# %% [markdown]
# ##Heat Map for missing values

# %%
plt.figure(figsize=(17, 5))
sns.heatmap(df.isnull(), cbar=True, yticklabels=False)
plt.xlabel("Column_Name", size=14, weight="bold")
plt.title("Places of missing values in column",fontweight="bold",size=17)
plt.show()

# %% [markdown]
# ##Unique Values In Each Feature Column

# %%
unique_df = pd.DataFrame()
unique_df['Features'] = df.columns
unique=[]
for i in df.columns:
    unique.append(df[i].nunique())
unique_df['Uniques'] = unique

f, ax = plt.subplots(1,1, figsize=(15,7))

splot = sns.barplot(x=unique_df['Features'], y=unique_df['Uniques'], alpha=0.8)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center',
                   va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.title('Bar plot for number of unique values in each column',weight='bold', size=15)
plt.ylabel('#Unique values', size=12, weight='bold')
plt.xlabel('Features', size=12, weight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##Plot of Top 15 Locations Of Tweet.

# %%
loc_analysis = pd.DataFrame(df['Location'].value_counts().sort_values(ascending=False))
loc_analysis = loc_analysis.rename(columns={'Location':'count'})

# %%
import plotly.graph_objects as go

# %%
data = {
   "values": loc_analysis['count'][:15],
   "labels": loc_analysis.index[:15],
   "domain": {"column": 0},
   "name": "Location Name",
   "hoverinfo":"label+percent+name",
   "hole": .4,
   "type": "pie"
}
layout = go.Layout(title="<b>Ratio on Location</b>", legend=dict(x=0.1, y=1.1, orientation="h"))

data = [data]
fig = go.Figure(data = data, layout = layout)
fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bb308246-44a9-45cc-8a3d-60a0468bbdb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb308246-44a9-45cc-8a3d-60a0468bbdb4")) {                    Plotly.newPlot(                        "bb308246-44a9-45cc-8a3d-60a0468bbdb4",                        [{"domain":{"column":0},"hole":0.4,"hoverinfo":"label+percent+name","labels":["London","United States","London, England","New York, NY","Washington, DC","United Kingdom","Los Angeles, CA","India","UK","Australia","USA","Canada","England, United Kingdom","Toronto, Ontario","Global"],"name":"Location Name","values":[540,528,520,395,373,337,281,268,232,225,223,191,191,160,159],"type":"pie"}],                        {"legend":{"orientation":"h","x":0.1,"y":1.1},"title":{"text":"<b>Ratio on Location</b>","x":0.5},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automa ...

# %%
'''
sns.catplot("TweetAt", data=df, kind="count", height=8)
plt.title('Bar plot for number of location in each column', weight='bold', size=15)
plt.ylabel('Count', size=12, weight='bold')
plt.xlabel('TweetAt', size=12, weight='bold')
plt.xticks(rotation=90)
plt.show()
'''
# Out:
# '\nsns.catplot("TweetAt", data=df, kind="count", height=8)\nplt.title(\'Bar plot for number of location in each column\', weight=\'bold\', size=15)\nplt.ylabel(\'Count\', size=12, weight=\'bold\')\nplt.xlabel(\'TweetAt\', size=12, weight=\'bold\')\nplt.xticks(rotation=90)\nplt.show()\n'

# %% [markdown]
# ##Top 10 locations of tweet

# %%
Top_Location_Of_tweet = df['Location'].value_counts()[:10]

#sns.set(rc={'figure.figsize':(12,8)})
#sns.set_style('white')

# %%
Top_Location_Of_tweet
# Out:
# London             540
# United States      528
# London, England    520
# New York, NY       395
# Washington, DC     373
# United Kingdom     337
# Los Angeles, CA    281
# India              268
# UK                 232
# Australia          225
# Name: Location, dtype: int64

# %%
Top_Location_Of_tweet_df=pd.DataFrame(Top_Location_Of_tweet)
Top_Location_Of_tweet_df.reset_index(inplace=True)
Top_Location_Of_tweet_df.rename(columns={'index':'Location', 'Location':'Location_Count'}, inplace=True)
Top_Location_Of_tweet_df
# Out:
#           Location  Location_Count
# 0           London             540
# 1    United States             528
# 2  London, England             520
# 3     New York, NY             395
# 4   Washington, DC             373
# 5   United Kingdom             337
# 6  Los Angeles, CA             281
# 7            India             268
# 8               UK             232
# 9        Australia             225

# %%
viz_1=sns.barplot(x="Location", y="Location_Count", data=Top_Location_Of_tweet_df,
                 palette='Blues_d')
viz_1.set_title('Locations with most of the tweets')
viz_1.set_ylabel('Count of listings')
viz_1.set_xlabel('Location Names')
viz_1.set_xticklabels(viz_1.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'London'),
#  Text(0, 0, 'United States'),
#  Text(0, 0, 'London, England'),
#  Text(0, 0, 'New York, NY'),
#  Text(0, 0, 'Washington, DC'),
#  Text(0, 0, 'United Kingdom'),
#  Text(0, 0, 'Los Angeles, CA'),
#  Text(0, 0, 'India'),
#  Text(0, 0, 'UK'),
#  Text(0, 0, 'Australia')]

# %% [markdown]
# ##Data Preprocessing
#
# A) Remove @user

# %%
# write function for removing @user

import re

def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i,'',input_txt)
    return input_txt

# %%
# create new column with removed @user

df['Tweet'] = np.vectorize(remove_pattern)(df['OriginalTweet'], '@[\w]*')

# %%
df.head(2)
# Out:
#    UserName  ScreenName Location     TweetAt  \
# 0      3799       48751   London  16-03-2020
# 1      3800       48752       UK  16-03-2020
#
#                                        OriginalTweet Sentiment  \
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...   Neutral
# 1  advice Talk to your neighbours family to excha...  Positive
#
#                                                Tweet
# 0     https://t.co/iFz9FAn2Pa and https://t.co/xX...
# 1  advice Talk to your neighbours family to excha...

# %% [markdown]
# B) Remove http and url from Tweet.

# %%
df['Tweet'] = df['Tweet'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

# %%
df.head(3)
# Out:
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
#
#                                        OriginalTweet Sentiment  \
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...   Neutral
# 1  advice Talk to your neighbours family to excha...  Positive
# 2  Coronavirus Australia: Woolworths to give elde...  Positive
#
#                                                Tweet
# 0
# 1  advice Talk to your neighbours family to excha...
# 2  Coronavirus Australia: Woolworths to give elde...

# %% [markdown]
# C) Remove Punctuations, Numbers, and Special Characters

# %%
df['Tweet'] = df['Tweet'].str.replace('[^a-zA-Z#]+',' ')

# %%
df.head(5)
# Out:
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
# 3      3802       48754        NaN  16-03-2020
# 4      3803       48755        NaN  16-03-2020
#
#                                        OriginalTweet           Sentiment  \
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...             Neutral
# 1  advice Talk to your neighbours family to excha...            Positive
# 2  Coronavirus Australia: Woolworths to give elde...            Positive
# 3  My food stock is not the only one which is emp...            Positive
# 4  Me, ready to go at supermarket during the #COV...  Extremely Negative
#
#                                                Tweet
# 0
# 1  advice Talk to your neighbours family to excha...
# 2  Coronavirus Australia Woolworths to give elder...
# 3  My food stock is not the only one which is emp...
# 4  Me ready to go at supermarket during the #COVI...

# %% [markdown]
# D) Remove Short Words

# %%
df['Tweet'] = df['Tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w) > 2]))

# %%
df.head(2)
# Out:
#    UserName  ScreenName Location     TweetAt  \
# 0      3799       48751   London  16-03-2020
# 1      3800       48752       UK  16-03-2020
#
#                                        OriginalTweet Sentiment  \
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...   Neutral
# 1  advice Talk to your neighbours family to excha...  Positive
#
#                                                Tweet
# 0
# 1  advice Talk your neighbours family exchange ph...

# %% [markdown]
# E) Tokenization

# %%
# create new feature tokenized tweet

tokenized_tweet = df['Tweet'].apply(lambda x: x.split())

# %%
df.head(2)
# Out:
#    UserName  ScreenName Location     TweetAt  \
# 0      3799       48751   London  16-03-2020
# 1      3800       48752       UK  16-03-2020
#
#                                        OriginalTweet Sentiment  \
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...   Neutral
# 1  advice Talk to your neighbours family to excha...  Positive
#
#                                                Tweet
# 0
# 1  advice Talk your neighbours family exchange ph...

# %% [markdown]
# F) Stemming

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

# apply stemmer for tokenized_tweet
tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x])

# %% [markdown]
# Understanding the common words used in the tweets: WordCloud

# %%
df.head(2)
# Out:
#    UserName  ScreenName Location     TweetAt  \
# 0      3799       48751   London  16-03-2020
# 1      3800       48752       UK  16-03-2020
#
#                                        OriginalTweet Sentiment  \
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...   Neutral
# 1  advice Talk to your neighbours family to excha...  Positive
#
#                                                Tweet
# 0
# 1  advice Talk your neighbours family exchange ph...

# %%
# create text from all tweets

all_words = ' '.join([text for text in df['Tweet']])

from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# create text from just extremely positive tweets

normal_words = ' '.join([text for text in df['Tweet'][df['Sentiment'] == 'Extremely Positive']])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# create text from just positive tweets

normal_words = ' '.join([text for text in df['Tweet'][df['Sentiment'] == 'Positive']])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# create text from extremely negative tweets

normal_words = ' '.join([text for text in df['Tweet'][df['Sentiment'] == 'Extremely Negative']])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# create text from negative tweets

normal_words = ' '.join([text for text in df['Tweet'][df['Sentiment'] == 'Negative']])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# create text from neutral tweets

normal_words = ' '.join([text for text in df['Tweet'][df['Sentiment'] == 'Neutral']])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ##Understanding the impact of Hashtags on tweets sentiment

# %%
# function to collect hashtags

def hashtag_extract(x):
    hashtags = []
    for i in x:
        ht = re.findall(r'#(\w+)', i)
        hashtags.append(ht)
    return hashtags

# %%
# extracting hashtags from non racist/sexist tweets

HT_Extremely_Positive = hashtag_extract(df['OriginalTweet'][df['Sentiment'] == 'Extremely Positive'])
HT_Positive = hashtag_extract(df['OriginalTweet'][df['Sentiment'] == 'Positive'])
HT_Neutral = hashtag_extract(df['OriginalTweet'][df['Sentiment'] == 'Neutral'])
HT_Negative = hashtag_extract(df['OriginalTweet'][df['Sentiment'] == 'Negative'])
HT_Extremely_Negative = hashtag_extract(df['OriginalTweet'][df['Sentiment'] == 'Extremely Negative'])

# %%
HT_Extremely_Positive
# Out:
# [[],
#  ['horningsea'],
#  [],
#  ['COVID2019',
#   'Trials',
#   'Monthly',
#   'Yearly',
#   'Prices',
#   'Subscriptions',
#   'bestiptv',
#   'iptv',
#   'Service',
#   'Iptv',
#   'iptvdeals',
#   'Cheap',
#   'ipTV',
#   'Football',
#   'HD',
#   'Movies',
#   'Adult',
#   'Cinema',
#   'hotmovies',
#   'iptvnew',
#   'iptv2020',
#   'Adult'],
#  ['COVID2019',
#   'Trials',
#   'Monthly',
#   'Yearly',
#   'Prices',
#   'Subscriptions',
#   'bestiptv',
#   'iptv',
#   'Service',
#   'Iptv',
#   'iptvdeals',
#   'Cheap',
#   'ipTV',
#   'Football',
#   'HD',
#   'Movies',
#   'Adult',
#   'Cinema',
#   'hotmovies',
#   'ipTv',
#   '18Movies'],
#  ['consumer', 'covid19', 'tracker'],
#  ['BreakingNews',
#   'Breaking',
#   'Coronavirus',
#   'CoronavirusOutbreak',
#   'COVID19',
#   'COVID',
#   'COVID_19',
#   'COVID2019',
#   'Collapse'],
#  ['CoronavirusOutbreak', 'coronavirus', 'COVID2019'],
#  ['jlmco',
#   'jlmcobrand',
#   'coronapocolypse',
#   'coronavirus',
#   'CoronavirusOutbreak',
#   'COVID19',
#   'shoponline'],
#  [],
#  ['coronavirus',
#   'COVID19',
#   'peoplearelosingtheirminds',
#   'StopTheMadness',
#   'stoppanicbuying'],
#  ['coronavirus', 'StopPanicBuying', 'BeKind', 'mufc', 'MUFC_Family'],
#  ['Malaysia2020', 'Malaysia', 'COVID'],
#  ['COVID2019'],
#  [],
#  ['QuarantineLife', 'COVID2019'],
#  ['COVID', 'Coronavirus'],
#  [],
#  [],
#  ['Corona', 'covid_19'],
#  ['coronavirus', 'coronapocolypse', 'panic', 'shopping'],
#  ['COVID', 'coronavirus'],
#  ['unitedagainstdementia', 'coronavirus'],
#  [],
#  ['coronavirus'],
#  [],
#  ['lottery',
#   'stockmarket',
#   'toiletpaper',
#   'Arizona',
#   'coronavirus',
#   'StopPanicBuying',
#   'FoxNews',
#   'fox10phoenix'],
#  [],
#  [],
#  ['coronavirus', 'CoronavirusOutbreak', 'Covid_19'],
#  [],
#  [],
#  ['workinghard', 'safety', 'DedicatedPeople'],
#  ['coronavirus', 'covid2019', 'coronavirusindia'],
#  [],
#  ['COVID19', 'MAbiz'],
#  ['CoronavirusPandemic', 'coronavirus', 'coronapocolypse'],
#  [],
#  ['COVID2019', 'COVID19', 'COVID'],
#  ['coronavirus'],
#  ['COVID19', 'marketresearch', 'consumerinsights'],
#  [],
#  [],
#  [],
#  [],
#  ['stopthespread', 'socialdistancing'],
#  ['COVID2019'],
#  [],
#  [],
#  ['Odisha', 'OdishaNews', 'OmmcomNews'],
#  ['ecommerce', 'retail', 'dtc', 'coronapocalypse', 'covid19'],
#  ['Covid19', 'coronaoutbreak', 'falsepanic', 'coronavirus', 'worldshutdown'],
#  ['coronavirus', 'applications'],
#  [],
#  [],
#  ['Coronavirus'],
#  ['coronavirus'],
#  ['coronavirus'],
#  [],
#  ['NewZealand', 'CPTPP'],
#  ['coronavirus'],
#  ['COVID19'],
#  ['COVID2019'],
#  ['SupremeCourt', 'coronavirus'],
#  ['coronavirusoutbreaks', 'COVID2019'],
#  [],
#  [],
#  ['coronavirus',
#   'mealplan',
#   'mealprep',
#   'stockup',
#   'coronapocolypse',
#   'HowToKeepPeopleHome',
#   'Covid_19',
#   'schoolclosure',
#   'QuarantineLife'],
#  ['coronavirus', 'supplychainmanagement'],
#  ['smart', 'Kuwait', 'online', 'sites', 'coronavirus', 'thankingkuwaitcorona'],
#  [],
#  ['Staythefuckhome', 'cinephile', 'stayhome', 'Covid_19'],
#  [],
#  ['coronapocolypse', 'coronavirus', 'Babyboom2020'],
#  [],
#  [],
#  ['ecommerce', 'shoplocal', 'coronavirus'],
#  [],
#  ['Coronavirus'],
#  [],
#  ['COVID'],
#  ['consumers',
#   'food',
#   'drink',
#   'beauty',
#   'retail',
#   'health',
#   'COVID19',
#   'marketresearch',
#   'consumerinsights',
#   'consumerbehavior',
#   'trustedsource'],
#  [],
#  ['COVID19'],
#  ['coronavirus'],
#  ['CoronaVirus'],
#  ['healthworkers', 'COVID19', 'coronavirus'],
#  ['affiliate', 'Coronavirus', 'COVID19'],
#  [],
#  ['nycs'],
#  ['coronavirus', 'Covid_19'],
#  [],
#  ['America', 'SickofWinning'],
#  ['coronavirus'],
#  ['coronavirus'],
#  [],
#  ['COVID2019', 'covid19houston'],
#  ['COVID2019'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['COVID2019'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Drive', 'coronavirus'],
#  ['coffee', 'COVID2019', 'ralphs', 'McDonaldsCoffee', 'GroceryStore'],
#  [],
#  ['Covid_19', 'US'],
#  [],
#  ['CoronaVirusSA', 'Coronavirussouthafrica', 'COVID2019'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  [],
#  ['COVID2019'],
#  [],
#  ['coronavirus'],
#  [],
#  [],
#  ['CoronavirusOutbreak', 'COVID2019', 'coronavirus'],
#  [],
#  ['immigrantsong', 'COVID19', 'coronavirus', 'canadalockdown'],
#  [],
#  [],
#  ['coronavirus'],
#  [],
#  ['COVID2019'],
#  ['COVID2019', 'coronavirus', 'panicbuying', 'GroceryStore'],
#  [],
#  [],
#  [],
#  ['coronavirus', 'bringmeauntjemima', 'finalstraw'],
#  [],
#  ['coronavirus'],
#  [],
#  [],
#  [],
#  [],
#  ['staysafe',
#   'stayhealthy',
#   'stockup',
#   'weareopen',
#   'corona',
#   'coronavirus',
#   'blissbakedgoods'],
#  ['coronavirus', 'LosAngeles'],
#  [],
#  ['coronavirus', 'Corvid19uk'],
#  ['COVID2019'],
#  ['COVID19'],
#  ['coronavirus'],
#  [],
#  ['health', 'COVID2019', 'coronavirus', 'CoronavirusOutbreak', 'nutrition'],
#  [],
#  ['fintech',
#   'contactless',
#   'coronavirus',
#   'payment',
#   'paytech',
#   'lendtech',
#   'processing',
#   'ach'],
#  ['coronavirus'],
#  ['coronavirus'],
#  ['StPatricksDay',
#   'StayAtHomeChallenge',
#   'firstresponders',
#   'grocerystores',
#   'COVID2019',
#   'ChineseVirus',
#   'TuesdayMorning'],
#  ['dollargeneral', 'COVID2019'],
#  ['arthritis', 'COVID2019'],
#  ['coronavirus'],
#  ['Euro2020', 'COVID2019', 'transfermarkt'],
#  ['coronavirus'],
#  ['COVID2019'],
#  ['shpk', 'yeg', 'yegfood', 'shoplocal', 'coronavirus', 'stockup'],
#  [],
#  [],
#  [],
#  [],
#  ['COVID2019', 'SocialDistancing'],
#  [],
#  ['COVID2019', 'coronavirus'],
#  ['coronavirus', 'CoronavirusOutbreak'],
#  ['COVID2019'],
#  ['iwillsurvive', '2020', 'covid_19', 'gasprices'],
#  ['coronavirus', 'pricegougers', 'ToryBritain'],
#  ['Amazon',
#   'Coronavirus',
#   'pandemic',
#   'CoronavirusOutbreak',
#   'COVID19',
#   'COVID19AB',
#   'Coronavirustoronto'],
#  [],
#  ['liveinhope', 'COVID2019', 'lockdown'],
#  [],
#  ['coronavirus', 'COVID19', 'pets', 'stockup'],
#  [],
#  [],
#  ['Tips', 'wellbeing'],
#  ['DowntownIthaca', 'IthacaNY'],
#  ['COVID2019'],
#  [],
#  ['madness'],
#  [],
#  [],
#  ['ElevensesWithEmmaBunting', 'COVID2019'],
#  ['COVID19'],
#  [],
#  ['economy', 'COVID2019', 'CoronavirusUSA'],
#  [],
#  [],
#  ['coronavirus',
#   'CoronavirusOutbreak',
#   'homequarantine',
#   'earth',
#   'Peace',
#   'Mask',
#   'Cleanlife',
#   'Cleancity',
#   'Cleanworld',
#   'StopTheSpread',
#   'StopPanicBuying',
#   'Designer',
#   'Awareness'],
#  [],
#  ['news', 'restaurants', 'explore'],
#  ['COVID2019', 'COVID19UK', 'coronavirus'],
#  ['coronavirus', 'ShelterInPlace'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['GroceryStore', 'Hoarding', 'coronapocolypse', 'Coronavirus'],
#  [],
#  [],
#  ['coronavirusaus', 'COVID2019', 'supermarketapocalypse'],
#  ['intellectualproperty', 'COVID19', 'ip'],
#  [],
#  [],
#  ['coronavirus'],
#  ['coronavirus',
#   'panic',
#   'Chaos',
#   'Goko',
#   'footprints',
#   'goko_restaurant',
#   'goko'],
#  ['coronavirus'],
#  ['Nielsen',
#   'behaviors',
#   'health',
#   'medicalcannabis',
#   'delivery',
#   'customerintelligence',
#   'cpg',
#   'retail',
#   'grassphealth'],
#  ['COVID2019'],
#  [],
#  [],
#  ['mostexpensiveholiday', 'COVID2019', 'VirginAtlantic', 'Virginholidays'],
#  ['OntAg'],
#  ['grocerystores',
#   'risinguptothechallenges',
#   'USA',
#   'GroceryStore',
#   'groceryshopping',
#   'COVID19',
#   'coronavirus'],
#  [],
#  [],
#  ['coronavirus', 'COVID19', 'BorisJohnson'],
#  ['Amazon', 'DigitalCapitalism'],
#  ['energy',
#   'COVID2019',
#   'Grocery',
#   'BeKind',
#   'FaithOverFear',
#   'loveistheanswer',
#   'PrayerForAPandemic'],
#  ['CoronavirusOutbreak',
#   'coronavirusuk',
#   'coronavirus',
#   'Munch',
#   'toiletpaper',
#   'toiletroll'],
#  ['HongKong', 'COVID2019'],
#  ['TogetherApart'],
#  [],
#  ['COVID2019', 'facemasks'],
#  ['COVID2019', 'Corvid19uk', 'stayhomechallenge'],
#  ['coronavirus', 'TuesdayMorning'],
#  ['COVID19',
#   'coronavirus',
#   'y2k',
#   'StopPanicBuying',
#   'itsrealthistime',
#   'FalloutShelter'],
#  [],
#  ['Covid_19'],
#  [],
#  ['covid19', 'Coronavirus', 'pandemic'],
#  ['COVID2019', 'ToiletPaperBlues'],
#  ['COVID2019', 'BeKind'],
#  [],
#  [],
#  ['COVID19', 'looroll', 'weredoomedmrmannering'],
#  ['staysafe',
#   'stayhomechallenge',
#   'coronavirus',
#   'workingfromhome',
#   'QuarantineLife'],
#  ['IllinoisPrimary', 'COVID2019', 'needfood', 'VoteBlue2020'],
#  ['coronavirus'],
#  ['COVID'],
#  [],
#  ['COVID2019', 'IDTwitter'],
#  ['QuarantineLife',
#   'Coronavirussouthafrica',
#   'CoronavirusOutbreak',
#   'COVID19KE',
#   'ChinaVirus',
#   'CoronaVirusChallenge',
#   'selfquarantine',
#   'COVID2019'],
#  ['covid19',
#   'nofood',
#   'stockpile',
#   'coronavirus',
#   'food',
#   'shopping',
#   'capitalism',
#   'noworries'],
#  ['coronavirus', 'marketing'],
#  ['Stoppanicbuying', 'Sheeple', 'coronavirus', 'justwashyourhands'],
#  ['COVID19', 'SD13', 'District13', 'Coronavirus'],
#  [],
#  ['COVID2019', 'coronavirus', 'spain'],
#  [],
#  ['Ehub', 'Covid_19'],
#  ['COVID2019'],
#  [],
#  ['COVID2019'],
#  [],
#  ['handsanitizer', 'product', 'DFS', 'sports', 'coronavirus'],
#  [],
#  ['COVID19',
#   'coronavirus',
#   'SocialDistancing',
#   'ShelterInPlace',
#   'StockMarket',
#   'StopPanicBuying'],
#  ['themarshacrawfordteam', 'marsha', 'compassrealestate'],
#  ['ninahossain'],
#  [],
#  ['coronavirus', 'Covoid19', 'hospitality'],
#  ['StayAtHome', 'COVID2019', 'stayhomechallenge', 'coronavirus', 'COVID19BE'],
#  [],
#  ['coronavirus', 'blackfriday'],
#  ['nonprofit'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  ['COVID2019'],
#  ['COVID19SouthAfrica', 'coronavirus'],
#  ['COVID19', 'COVID', 'COVID_19', 'CoronavirusOutbreak'],
#  ['coronavirus'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['COVID2019', 'MaukepeChauka'],
#  ['coronavirus', 'COVID19', 'CripTheVote'],
#  [],
#  ['APOCALYPSE',
#   'hysteria',
#   'FakeNews',
#   'Inslee',
#   'panic',
#   'coronavirus',
#   'WakeUp',
#   'QAnon'],
#  ['COVID2019'],
#  ['coronavirus'],
#  [],
#  ['COVID2019', 'coronavirus'],
#  ['Safeway', 'COVID2019', 'fightingcoronavirus'],
#  ['Covid_19'],
#  ['COVID2'],
#  ['itsnottheendoftheworld', 'coronavirus'],
#  [],
#  [],
#  ['nosocialdistance',
#   'kidsattheplayground',
#   'menhangingout',
#   'itsapartyoutthere',
#   'coronavirus',
#   'losangeles'],
#  ['COVID19', 'restaurant'],
#  [],
#  ['Covid'],
#  [],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  ['Crypto', 'Bitcoin', 'coronavirus', 'COVID19', 'TimeForPlanB'],
#  ['Brand', 'Communications', 'COVID19'],
#  ['coronavirus'],
#  ['covid_19'],
#  ['anxiety',
#   'isolation',
#   'COVID19',
#   'mentalhealth',
#   'therapy',
#   'anxietytherapy'],
#  ['coronavirus', 'coronavirus', 'toiletpaper', 'stayhomechallenge', 'stockup'],
#  ['COVID2019'],
#  [],
#  [],
#  ['Coronavirus', 'Retail'],
#  [],
#  [],
#  ['Coronavirus'],
#  ['ColoradoStrong', 'coronavirus'],
#  ['Walmart', 'MSGulfCoast'],
#  ['COVID19', 'cdnpoli'],
#  [],
#  ['COVID2019', 'SupportLocalBusinesses'],
#  ['Support', 'COVID2019'],
#  [],
#  [],
#  ['COVID19'],
#  ['COVID2019'],
#  ['coronavirus', 'selfquarantine'],
#  ['coronavirus'],
#  ['coronavirus'],
#  ['coronavirus'],
#  [],
#  [],
#  ['COVID2019'],
#  ['coronavirus', 'panicshopping'],
#  [],
#  ['COVID19'],
#  ['stayhomechallenge',
#   'bathroom',
#   'coronavirus',
#   'Awareness',
#   'AwardsForMillennials',
#   'Parents',
#   'Online',
#   'shopping'],
#  ['cfprobs', 'isolation', 'coronavirus'],
#  ['coronavirus', 'COVID'],
#  ['COVID2019', 'StayAtHome'],
#  [],
#  ['COVID2019', 'InItTogether', 'PanicBuying'],
#  ['retail', 'Coronavirus', 'BathAndBodyWorks'],
#  [],
#  ['health',
#   'stayhome',
#   'homegym',
#   'boxing',
#   'coronavirus',
#   'covid19',
#   'world',
#   'pray',
#   'GOD'],
#  [],
#  ['coronavirus'],
#  [],
#  ['COVID2019'],
#  [],
#  ['coronavirus', 'dontripusoff', 'lookaftereachother', 'befair'],
#  [],
#  [],
#  ['COVID2019',
#   'CoronavirusOutbreak',
#   'coronapocolypse',
#   'COVID2019uk',
#   'panicshopping'],
#  [],
#  [],
#  ['WIN', 'sobeys', 'COVID2019', 'coronavirus'],
#  ['COVID2019'],
#  [],
#  [],
#  ['coronavirus', 'retail'],
#  ['Coronavirus'],
#  [],
#  ['CoronaVirus',
#   'TWGRP',
#   'WhiteHouse',
#   'LeadRight',
#   'MAGA',
#   'MAGA2020',
#   'KAG',
#   'KAG2020',
#   'Trump2020LandslideVictory'],
#  ['12News'],
#  [],
#  ['30Seconds', 'coronavirus', 'pantry', 'food', 'stockingup'],
#  ['COVID2019', 'CoronavirusOutbreak'],
#  [],
#  [],
#  ['NotAllHeroesWearCapes', 'COVID2019'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['covid19UK', 'panicbuying', 'coronavirus'],
#  [],
#  ['coronavirus'],
#  [],
#  ['sdbeer', 'COVID2019'],
#  ['coronavirus'],
#  ['CoronaVirus'],
#  ['COVID2019'],
#  ['COVID2019'],
#  [],
#  [],
#  ['Coronavirus'],
#  ['StopPanicBuying', 'sainsburys', 'Norwich', 'covid19UK', 'coronavirus'],
#  [],
#  [],
#  [],
#  ['WFHTips', 'coronavirus', 'LSUHFNO'],
#  ['consumer', 'psychology'],
#  [],
#  [],
#  ['CancelStudentDebt'],
#  ['coronavirus', 'Quarantine'],
#  [],
#  ['coronavirus', 'consumer', 'peopleÂ'],
#  ['coronavirus', 'COVID19'],
#  ['coronavirus'],
#  [],
#  ['COVID19',
#   'America',
#   'JobSeekersWednesday',
#   'HIRINGNOW',
#   'coronavirus',
#   'grocery',
#   'Jobs',
#   'JobSearch',
#   'opportunity',
#   'JobAlert',
#   'COVID'],
#  ['nonprofit'],
#  [],
#  ['toiletpaper', 'handsanitiser', 'nothappyJan', 'coronavirus'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['pantrystaples', 'quarantineandchill'],
#  ['COVID2019'],
#  [],
#  [],
#  [],
#  ['Covid_19'],
#  ['Fiverr',
#   'californialockdown',
#   'OprahWinfrey',
#   'wix',
#   'websites',
#   'COVID2019',
#   'CoronavirusOutbreak'],
#  ['COVID19', 'COVID2019'],
#  ['coronavirus', 'Trucking', 'Retail', 'business', 'BusinessAsUsual'],
#  ['covid19UK', 'CoronavirusOutbreak', 'coronavirus'],
#  [],
#  ['coronavirus'],
#  [],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  [],
#  ['WiseWednesday', 'workfromhome', 'coronavirus'],
#  ['coronavirus'],
#  ['handsanitizer', 'coronavirus', 'handwashing', 'lupehernandez', 'latina'],
#  [],
#  ['Covid19', '2020Undefeated', 'ReviveTheEconomy', 'Push', 'HelpTheEarth'],
#  ['covid19UK'],
#  [],
#  ['frontlineheroes',
#   'COVID19',
#   'coronavirus',
#   'CoronaVirusChallenge',
#   'Thankyou'],
#  [],
#  ['coronavirus', 'GroceryStore', 'WednesdayMotivation'],
#  ['FactsNotFear', 'COVID19', 'coronavirus'],
#  [],
#  ['COVID19'],
#  [],
#  [],
#  [],
#  ['Auspol', 'coronavirusaustralia'],
#  [],
#  ['CORONAVIRUS', 'LasVegas'],
#  ['coronavirus'],
#  ['DSHCOVID19'],
#  ['COVID19'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['VapeFam'],
#  ['SchoolsClosure', 'coronavirus'],
#  ['Coronavirus', 'CapitalReports'],
#  ['CoronaVirus', 'WIC', 'CompassionateCommunity'],
#  ['Nameandshame', 'COVID19UK', 'coronavirus'],
#  [],
#  [],
#  [],
#  ['COVID2019'],
#  ['coronavirus'],
#  ['Coronavirus'],
#  ['Covid_19'],
#  ['coronavirus', 'EssentialWorkerWage'],
#  ['coronavirus'],
#  ['coronavirus', 'coÂ'],
#  [],
#  [],
#  ['coronavirus'],
#  ['CoronavirusOutbreak', 'andrex', 'boycott', 'tesco', 'coronavirus'],
#  ['unsungheroes', 'COVID2019', 'panicbuying'],
#  ['gratitude',
#   'frontliners',
#   'real',
#   'heros',
#   'fighting',
#   'bravely',
#   'covid_19',
#   'covid_2019',
#   'coronovirus'],
#  ['coronavirus'],
#  ['coronaactofkindness', 'coronavirus'],
#  [],
#  [],
#  ['Lorain', 'coronavirus'],
#  ['coronavirus', 'covid19', 'foodandbeverage', 'retail', 'ecommerce'],
#  [],
#  ['Tesco', 'Morrissons', 'Sainsbury', 'Lidl', 'Aldi', 'COVID2019'],
#  ['COVID2019'],
#  [],
#  [],
#  [],
#  [],
#  ['HandSanitizer', 'Coronavirus', 'COVAD19', 'CraftSpirits'],
#  [],
#  [],
#  ['BuyBooks', 'coronavirus', 'Trump'],
#  [],
#  ['coronavirus', 'hoarding', 'nofood', 'toiletpapershortage'],
#  ['Superdry',
#   'Coronavirus',
#   'Covid19',
#   'retail',
#   'retailnews',
#   'fashion',
#   'fashionnews',
#   'onlinesales'],
#  ['Coronavirus', 'FuckYouPayMe'],
#  [],
#  ['coronavirus'],
#  ['ProMach', 'EPI', 'Labelers'],
#  [],
#  ['Cheerios', 'packaged', 'coronavirus'],
#  [],
#  ['coronavirus'],
#  [],
#  ['COVID2019'],
#  ['journorequest', 'COVID2019', 'coronavirus'],
#  ['coronavirus', 'Turkey', 'China'],
#  [],
#  ['COVID19'],
#  ['COVID19'],
#  ['COVID19', '2Good2BTrue', 'staysafe', 'cyberstronghold'],
#  [],
#  [],
#  [],
#  ['USDCAD', 'Commodities', 'Coronavirus', 'Majors', 'Currencies'],
#  ['Repost'],
#  ['Covid_19'],
#  ['COVID19', 'support', 'community'],
#  ['coronavirus', 'retailnews', 'CoronavirusOutbreak'],
#  [],
#  ['coronavirus', 'QAnon'],
#  ['Covid_19', 'CoronaOutbreak', 'CoronavirusOutbreak', 'coronapocalypse'],
#  ['diives', 'gaghs', 'coronavirus', 'xingzuotemple'],
#  ['COVID2019', 'Covid19uk'],
#  ['covid19UK', 'COVID2019', 'StayHome'],
#  ['COVID2019'],
#  [],
#  ['NHS',
#   'COVID19',
#   'CoronavirusOutbreak',
#   'Virus',
#   'Coronavirus',
#   'UK',
#   'Schools',
#   'Food',
#   'Money',
#   'Struggling',
#   'PMQs',
#   'Government',
#   'PM'],
#  [],
#  ['coronavirus', 'COVID2019', 'CoronavirusOutbreak', 'COVID19'],
#  ['COVID2019'],
#  [],
#  [],
#  ['coronavirus'],
#  ['telehealth'],
#  ['COVID2019'],
#  [],
#  [],
#  ['CoronaVirus', 'Amazon'],
#  [],
#  ['coronavirus'],
#  [],
#  [],
#  ['coronavirus'],
#  ['coronavirus', 'COVID19', 'cf97'],
#  [],
#  [],
#  ['jmfamilyIMPACT'],
#  ['1', 'coronavirus'],
#  ['coronavirus'],
#  ['Coronavirus'],
#  [],
#  ['onlineshopping', 'coronavirus'],
#  ['coronavirus', 'Pandemic'],
#  [],
#  ['elderly'],
#  [],
#  ['payitforward', 'COVID19', 'coronavirus', 'supportsmallbusiness'],
#  [],
#  ['COVID19', 'coronavirus', 'edchat'],
#  [],
#  ['COVID19',
#   'stayhomechallenge',
#   'selfquarantine',
#   'SelfIsolation',
#   'coronavirus',
#   'StopPanicBuying'],
#  [],
#  [],
#  ['Coronavirus'],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  ['coronavirus'],
#  [],
#  ['COVID2019'],
#  ['coronavirus'],
#  ['coronavirus'],
#  [],
#  ['coronavirus', 'CoronavirusOutbreak'],
#  [],
#  ['covid_19',
#   'Covid19',
#   'Coronavirus',
#   'shopping',
#   'PanicBuying',
#   'StopPanicBuying',
#   'StopFuckingPanicBuying',
#   'flour',
#   'MaryBerry',
#   'TheGreatBritishBakeOff',
#   'tgbbo',
#   'gbbo'],
#  ['coronavirus', 'dontstockpile'],
#  [],
#  ['Florida', 'CNN', 'coronavirus'],
#  [],
#  ['coronavirus'],
#  [],
#  [],
#  ['coronavirus'],
#  [],
#  ['coronavirus', 'CoronavirusOutbreak', 'COVID19'],
#  ['coronavirus'],
#  ['coronavirus', 'COVID19', 'CoronavirusOutbreak'],
#  ['coronavirus', 'covid19'],
#  ['coronavirus', 'COVID19', 'SocialDistancing'],
#  ['coronavirus', 'StopPanicBuying'],
#  ['coronavirus', 'Takecareofeachother', 'Cleveland', 'ThisIsAMess'],
#  ['coronavirus'],
#  ['Guildford', 'coronavirus'],
#  ['CBD', 'CORONAVIRUS'],
#  ['CBD', 'CORONAVIRUS'],
#  ['CBD', 'CORONAVIRUS', 'keep'],
#  [],
#  ['smallbusinesses', 'Toronto', 'giftcards'],
#  ['Coronavirus'],
#  ['clean', 'coronavirus', 'supermarket', 'messagewrap'],
#  ['Coronavirus'],
#  ['coronavirus', 'Sky', 'NoShame', 'NoSense', 'CancelSky'],
#  ['HEB', 'COVID2019', 'coronavirus'],
#  ['quarantine', 'coronavirus'],
#  ['coronavirus', 'StopPanicBuying'],
#  [],
#  ['covid19', 'coronavirus', 'goldersgreen', 'hampsteadgardensuburb', 'nw11'],
#  [],
#  ['smallbusiness',
#   'BusinessContinuity',
#   'businessgrowth',
#   'businessnews',
#   'covid2019',
#   'CoronaVirus'],
#  ['corona', 'covid_19', 'supermarket'],
#  [],
#  [],
#  ['coronavirus'],
#  ['NCTECHmember', 'COVID19', 'MembersHelpingMembers'],
#  ['Walmart', 'Charmin', 'Christmas', 'coronavirus'],
#  ['Odisha', 'CoronaVirus', 'Register4Covid19SafeOdisha'],
#  ['COVID2019',
#   'ProtectTheVulnerable',
#   'StopPanicBuying',
#   'threeitemsonly',
#   'helpingothers'],
#  ['COVID2019',
#   'ProtectTheVulnerable',
#   'threeitemsonly',
#   'StopPanicBuying',
#   'helpingothers',
#   'CalmCOVID19'],
#  ['stayhealthy',
#   'staysafe',
#   'coronavirusfacts',
#   'wellnesswednesday',
#   'factsnotfear'],
#  ['COVID19', 'CoronaVirus'],
#  ['Tesco', 'disabled', 'elderly', 'coronavirus'],
#  [],
#  ['COVID2019', 'coronavirus'],
#  [],
#  ['COVID19', 'coronavirus'],
#  ['CoronaVirus', 'Covid19'],
#  ['COVID19', 'Trump', 'coronavirus'],
#  ['covid19', 'coronavirus'],
#  ['Trump', 'coronavirus', 'pandemic'],
#  ['coronavirus'],
#  ['coronavirus', 'Corvid19'],
#  ['COVID2019', 'edutwitter'],
#  ['weirdstreamathon', 'COVID_19', 'alonetogether', 'covid19'],
#  ['coronavirus'],
#  ['ebayuk', 'coronavirus'],
#  ['coronavirus'],
#  ['execpay', 'compensation', 'corpgov', 'COVID19', 'coronavirus'],
#  ['covid'],
#  ['Democratic', 'coronavirus', 'GiveBlood'],
#  ['COVID2019'],
#  ['COVID2019', 'workingfromhome'],
#  ['Odisha', 'COVID2019', 'WorldConsumerRightsDay'],
#  [],
#  ['covid19', 'queenspasta', 'toronto', 'canada', 'instagram'],
#  [],
#  ['Geneva', 'Covid_19', 'StaySafe'],
#  ['coronavirus'],
#  ['RPMAlamo', 'SanAntonioPropertyManagement', 'NewListingSanAntonio'],
#  [],
#  [],
#  [],
#  ['COVID19', 'coronavirus'],
#  [],
#  ['RCS', 'COVID19', 'staysafe', 'washyourhands'],
#  ['coronavirus'],
#  ['socialdistancing', 'covid19'],
#  ['coronavirus', 'toiletpaper', 'Bread', 'MothersDay'],
#  ['Food',
#   'thought',
#   'companies',
#   'saved',
#   'surplus',
#   'economic',
#   'coronavirus',
#   'StockMarket'],
#  [],
#  ['coronavirus'],
#  [],
#  ['BoycottHUL', 'Coronavirus'],
#  [],
#  [],
#  ['Covid19', 'hipaa'],
#  ['coronavirusnz', 'COVID19nz', 'panicbuying'],
#  ['coronavirus'],
#  [],
#  [],
#  [],
#  ['COVID2019'],
#  ['coronavirus',
#   'update',
#   'fortheculture',
#   'airsoft',
#   'airsofter',
#   'speedqb',
#   'speedsoft',
#   'COVID2019'],
#  [],
#  ['COVID2019', 'coronavirus'],
#  ['Coronavirus',
#   'TeamPete',
#   'TeamPeteForever',
#   'RulesOfTheRoad',
#   'Respect',
#   'Teamwork',
#   'Responsibility',
#   'Discipline',
#   'Excellence'],
#  ['healthybody', 'healthyfood', 'covid19', 'coronavirus'],
#  [],
#  ['communityspirit', 'coronavirus'],
#  ['covid_19'],
#  ['Coronavirus'],
#  [],
#  [],
#  ['staycalm', 'coronavirus', 'staysafe'],
#  [],
#  ['coronavirus', 'Covid19'],
#  ['theweeklyshop',
#   'COVID2019',
#   'covid19UK',
#   'lockdown',
#   'shopping',
#   'vulnerablegroups'],
#  ['coronavirus', 'StayAtHome'],
#  ['coronavirus'],
#  [],
#  ['coronavirus', 'pandemic'],
#  [],
#  ['handsanitizer', 'pricegouging', 'coronavirus'],
#  [],
#  ['coronavirus'],
#  ['coronavirus'],
#  [],
#  ['coronavirus', 'covid_19'],
#  ['coronavirus', 'covidindia', 'COVID2019', 'BoycottHUL'],
#  ['Cashier', 'coronavirus'],
#  ['Supermarkets', 'coeliacs', 'lactose', 'covid19UK', 'coronavirus'],
#  ['SocialDistancing', 'coronavirus'],
#  ['coronavirus', 'isolation', 'panickbuyers'],
#  ['CoronaVirus', 'SelfDistancing', 'HEB'],
#  ['COVID19'],
#  ['coronavirus', 'Covid19UK'],
#  [],
#  ['txlege'],
#  ['Coronavirus', 'sustainabilitystartswithyou', 'covid19'],
#  [],
#  [],
#  ['coronavirus'],
#  ['SocialDistancing', 'coronavirus', 'EnglishMuffins', 'Food', 'Recipe'],
#  ['COVID19', 'WeAreInThisTogether'],
#  [],
#  ['COVID19', 'StayAtHome', 'SwitchToStandard'],
#  ['coronavirus', 'COVID19'],
#  ['poortiming', 'coronavirus'],
#  ['coronavirus'],
#  ['primark', 'COVID2019', 'CovidUK', 'co'],
#  ['Boris', 'PMQs', 'COVID19', 'coronavirus'],
#  [],
#  ['US', 'government', 'COVID_19', 'COVID19au'],
#  ['European',
#   'Hospitals',
#   'COVID19',
#   'pandemic',
#   'Private',
#   'Europe',
#   'coronavirus'],
#  ['covid19UK'],
#  [],
#  [],
#  ['naturaldeodorantthatworks', 'crueltyfree', 'veganbeauty', 'coronavirus'],
#  ['shopping', 'Coronavirus', 'Covid19'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['guin'],
#  ['coronavirus'],
#  ['coronavirus',
#   'lockdown',
#   'groceries',
#   'supermarket',
#   'stock',
#   'iorestoacasa',
#   'andratuttobene',
#   'italy',
#   'tuscany',
#   'thankful'],
#  ['COVID19', 'coronavirus'],
#  [],
#  ['ESA', 'coronavirus', 'covid19UK', 'COVID19', 'coronavirusuk'],
#  ['Coronavirus'],
#  ['toiletpaper',
#   'batsoup',
#   'batburger',
#   'batstew',
#   'batmeatloaf',
#   'batsandwich',
#   'batandchips',
#   'deepfriedbat',
#   'covid19',
#   'coronavirus'],
#  ['Pakistan', 'Coronavirus'],
#  ['COVID19', 'CloseTheMalls', 'coronavirus'],
#  [],
#  ['COVID19', 'covid19UK', 'coronavirus', 'rationing', 'StopPanicBuying'],
#  ['supermarket', 'COVID2019', 'loyalty', 'businessman', 'localbusiness'],
#  ['coronavirus', 'coronaviruspandemic', 'ecommerce', 'business'],
#  [],
#  ['coronavirus', 'Tesco', 'BeKind', 'COVID2019'],
#  ['shoplocal'],
#  ['coronavirus'],
#  [],
#  [],
#  ['coronavirus', 'COVID19', 'Covid_19'],
#  [],
#  ['grateful', 'coronavirus'],
#  [],
#  ['WeAreInThisTogether'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['coronavirus',
#   'NoFood',
#   'NoTP',
#   'NoGas',
#   'Insanity',
#   'DoTheRightThing',
#   'KRINO',
#   'hiphop',
#   'NewERA',
#   'StayStrong'],
#  [],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  [],
#  [],
#  ['coronavirus', 'QuarantineLife'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['coronavirusuk', 'coronavirus'],
#  [],
#  ['Empath', 'PositiveVibes', 'Coronavirus'],
#  ['COVID19', 'coronavirus'],
#  ['coronavirus'],
#  [],
#  ['coronavirus',
#   'covid19UK',
#   'COVID19',
#   'selfisolation',
#   'SocialDistancing',
#   'shopping',
#   'SocialDistancingNow'],
#  [],
#  [],
#  ['coronavirus', 'COVID19'],
#  ['ADPHC', 'Towards_a_healthy_and_safe_society', 'Covid19', 'Coronavirus'],
#  ['renewannewithane', 'coronavirus'],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  ['COVID19', 'Nisa', 'coronavirus'],
#  [],
#  ['selfisolation', 'coronavirus', 'family', 'SocialDistance', 'StayAtHome'],
#  ['Publix',
#   'WinnDixie',
#   'Aldis',
#   'BigLots',
#   'youdamvp',
#   'coronavirus',
#   'COVID19',
#   'ToiletPaperApocalypse'],
#  ['supermarket',
#   'Supermarkets',
#   'Tesco',
#   'Sainsbury',
#   'Lidl',
#   'Asda',
#   'Morrisons',
#   'panicbuying',
#   'panicbuyers',
#   'foodshortages',
#   'emptyshelves',
#   'fooddelivery',
#   'food',
#   'virus',
#   'Covid_19',
#   'coronavirusuk',
#   'coronavirus'],
#  ['RetailWorkers', 'grocerystoreworkers', 'coronavirus'],
#  ['Coronavirus',
#   'DigitalMedia',
#   'DigitalMarketers',
#   'Pandemic',
#   'coronavirusindia',
#   'Covid19'],
#  ['COVID19', 'coronavirus', 'covidtoronto'],
#  ['ShopLocal'],
#  ['coronavirus',
#   'socialdistancing',
#   'stayathome',
#   'stayhomeforus',
#   'COVID2019AU',
#   'medtwitter'],
#  [],
#  ['Coronavirus'],
#  ['COVID19ON', 'COVID19', 'COVIDCanada', 'COVID2019'],
#  [],
#  ['coronavirus'],
#  [],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  ['COVID'],
#  [],
#  [],
#  ['coronavirus'],
#  [],
#  [],
#  [],
#  [],
#  ['StateOfEmergency', 'Covid_19'],
#  [],
#  ['Gold'],
#  [],
#  [],
#  ['Covid_19'],
#  ['COVID2019'],
#  [],
#  ['merehumanity', 'covid19UK', 'coronavirus'],
#  [],
#  [],
#  ['Coronavirus', 'GetUpDC'],
#  [],
#  ['Coronavirus'],
#  [],
#  ['coronavirus'],
#  [],
#  ['coronavirus', 'TrumpVirus2020', 'TrumpPressConference'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Americans', 'coronavirus', 'duty'],
#  [],
#  [],
#  ['coronavirus', 'saveworkers', 'stlblues', 'STLouis', 'STL'],
#  [],
#  ['RanjanGogoi', 'RajyaSabha'],
#  ['coronavirus', 'PPP'],
#  ['johnclive', 'coronavirus', 'panicbuying', 'hoarding', 'supermarket'],
#  ['coronavirus'],
#  [],
#  ['coronavirus'],
#  [],
#  ['coronavirus'],
#  [],
#  ['Covid_19', 'coronavirus'],
#  ['auspol'],
#  ['COVID19', 'CoronaVirus'],
#  [],
#  ['ChineseWuhanVirus', 'coronavirus', 'lockdownuk', 'FightCOVID19'],
#  [],
#  ['coronavirus', 'CoronaVirusUpdate', 'coronavirusnewyork', 'Coronavirusnyc'],
#  ['panicbuying', 'StopPanicBuying', 'covid19UK', 'coronavirus'],
#  [],
#  [],
#  ['coronavirus', 'electionyear', 'QuarantineLife', 'CoronaVirusUpdate'],
#  [],
#  [],
#  ['Coronavirus',
#   'Vegas',
#   'Summerlin',
#   'Boulder',
#   'CCSD',
#   'CCSDNEWS',
#   'VEGASNEWS'],
#  ['coronavirus'],
#  ['CoronavirusInSA', 'CoronaVirusUpdate', 'Covid_19', 'sabcnews'],
#  [],
#  ['Covid_19', 'Yeswaystores'],
#  ['AmericanCompassion', 'ProtectOurSeniors'],
#  ['CBDOilBenefitz',
#   'marijuana',
#   'cannabis',
#   'save',
#   'money',
#   'homegrow',
#   'growers',
#   'buyinbulk',
#   'wholesale',
#   'cbd',
#   'hempoil',
#   'budget',
#   'finances',
#   'coronavirus',
#   'beprepared',
#   'stockup',
#   'selfsufficient'],
#  [],
#  [],
#  [],
#  ['COVID'],
#  ['COVID19', 'COVID19nz'],
#  ['COVID19', 'stockpiling'],
#  [],
#  ['ThinkOfOthers', 'coronavirus', 'DontBeSelfish', 'COVID19'],
#  ['coronavirus'],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  ['coronavirusNederland',
#   'coronavirus',
#   'COVID19',
#   'CoronaVirusUpdate',
#   'CoronaCrisis',
#   'SocialDistanacing',
#   'netherlands'],
#  ['coronavirus', 'COVID2019', 'thankyou'],
#  [],
#  ['coronavirus'],
#  ['chezamy',
#   'coronavirus',
#   'covid_19',
#   'quarantinelife',
#   'stayhealthymyfriends'],
#  ['covid19', 'coronavirus', 'pandamonium', 'norespect', 'nofood'],
#  [],
#  [],
#  ['coronavirus', 'COVID19'],
#  [],
#  ['schoolclosuresuk', 'Coronavirus'],
#  ['coronavirus', 'retailvscorona', 'parentingfail'],
#  [],
#  [],
#  ['covid_19'],
#  [],
#  [],
#  ['COVID', 'seafood', 'wildalaskapollock'],
#  ['COVID19', 'Quarantine', 'coronavirus', 'diet', 'pandemic'],
#  [],
#  ['coronavirus'],
#  [],
#  ['CoronaVirus', 'WakeUp'],
#  ['coronavirus',
#   'COVID19',
#   'caregiving',
#   'caregivers',
#   'SeniorCare',
#   'eldercare',
#   'COVID19US'],
#  [],
#  ['gratitude', 'coronavirus'],
#  [],
#  [],
#  ['CoronaVirusChallenge', 'coronavirus', 'COVID19', 'CoronaVirusUpdate'],
#  [],
#  ['Covid19', 'CoronaVirus'],
#  ['Coronavirus'],
#  ['coronavirus', 'socialcare'],
#  ['realheros', 'coronavirus', 'corona'],
#  ['coronavirus', 'jantacurfew', 'FightCOVID19', 'CoronavirusOutbreakindia'],
#  ['COVID19', 'coronavirus', 'usa', 'politics', 'trump'],
#  ['coronavirusmusician', 'coronavirus'],
#  ['COVID19',
#   'coronavirus',
#   'toiletpaper',
#   'hoarders',
#   'panicroom',
#   'HomeswithDiane',
#   'servingYOURfamily',
#   'remax',
#   'realestate',
#   'realtor',
#   'centralindiana'],
#  [],
#  [],
#  [],
#  ['NY', 'coronavirus', 'COVID19', 'StayHome', 'CoronavirusPandemic'],
#  ['coronavirus', 'COVID19', 'Heroes'],
#  ['covid19UK', 'coronavirus'],
#  ['UNICEF', 'COVID19', 'CoronaVirus', 'CoronaOutbreak'],
#  ['AmitabhBachchan', 'coronavirus', 'COVID2019', 'IndiaFightsCorona'],
#  [],
#  ['Bogota', 'coronavirus', 'CoronavirusEnColombia'],
#  ['ElDorado',
#   'Brookshires',
#   'Shopping',
#   'Coronavirus',
#   'COVID19',
#   'SeniorDiscount',
#   'SeniorHours',
#   'UnionCounty'],
#  [],
#  ['coronavirus', 'COVID19'],
#  [],
#  ['COVID19', 'coronavirus', 'CoronavirusOutbreak'],
#  ['coronavirus'],
#  [],
#  ['coronavirus'],
#  ['COVID19', 'Sanitizer', 'Coronavirus'],
#  ['facemask',
#   'N95',
#   'coronavirus',
#   'MyQuarantineInSixWords',
#   'COVID19',
#   'Quarantine',
#   'ChineseCoronaVirus',
#   'SocialDistancing',
#   'Survivor40',
#   'BLEACH2020',
#   'COVID'],
#  [],
#  ['Coronavirus', 'COVID19'],
#  ['coronavirus', 'COVID19', 'CoronavirusOutbreak', 'COVID19ON'],
#  ['health', 'COVID19', 'COVIDCanada'],
#  ['FarmTank'],
#  ['covid19UK', 'coronavirus', 'COVID19'],
#  ['Irvine', 'COVID2019'],
#  [],
#  ['Covid_19', '4IR', '4IR', 'CoronavirusInSA'],
#  [],
#  [],
#  [],
#  ['coronavirus'],
#  [],
#  ['COVID19', 'coronavirus'],
#  [],
#  ...]

# %%
# unnesting list ---> finding the sum of the same hashtags in each list

HT_Extremely_Positive = sum(HT_Extremely_Positive, [])
HT_Positive = sum(HT_Positive, [])
HT_Neutral = sum(HT_Neutral, [])
HT_Negative = sum(HT_Negative,[])
HT_Extremely_Negative = sum(HT_Extremely_Negative,[])

# %%
print(HT_Extremely_Positive)
# Out:
# ['horningsea', 'COVID2019', 'Trials', 'Monthly', 'Yearly', 'Prices', 'Subscriptions', 'bestiptv', 'iptv', 'Service', 'Iptv', 'iptvdeals', 'Cheap', 'ipTV', 'Football', 'HD', 'Movies', 'Adult', 'Cinema', 'hotmovies', 'iptvnew', 'iptv2020', 'Adult', 'COVID2019', 'Trials', 'Monthly', 'Yearly', 'Prices', 'Subscriptions', 'bestiptv', 'iptv', 'Service', 'Iptv', 'iptvdeals', 'Cheap', 'ipTV', 'Football', 'HD', 'Movies', 'Adult', 'Cinema', 'hotmovies', 'ipTv', '18Movies', 'consumer', 'covid19', 'tracker', 'BreakingNews', 'Breaking', 'Coronavirus', 'CoronavirusOutbreak', 'COVID19', 'COVID', 'COVID_19', 'COVID2019', 'Collapse', 'CoronavirusOutbreak', 'coronavirus', 'COVID2019', 'jlmco', 'jlmcobrand', 'coronapocolypse', 'coronavirus', 'CoronavirusOutbreak', 'COVID19', 'shoponline', 'coronavirus', 'COVID19', 'peoplearelosingtheirminds', 'StopTheMadness', 'stoppanicbuying', 'coronavirus', 'StopPanicBuying', 'BeKind', 'mufc', 'MUFC_Family', 'Malaysia2020', 'Malaysia', 'COVID', 'COVID2019', 'QuarantineLife', 'COVID2019', 'COVID', 'Coronavirus', 'Corona', 'covid_19', 'coronavirus', 'coronapocolypse', 'panic', 'shopping', 'COVID', 'coronavirus', 'unitedagainstdementia', 'coronavirus', 'coronavirus', 'lottery', 'stockmarket', 'toiletpaper', 'Arizona', 'coronavirus', 'StopPanicBuying', 'FoxNews', 'fox10phoenix', 'coronavirus', 'CoronavirusOutbreak', 'Covid_19', 'workinghard', 'safety', 'DedicatedPeople', 'coronavirus', 'covid2019', 'coronavirusindia', 'COVID19', 'MAbiz', 'CoronavirusPandemic', 'coronavirus', 'coronapocolypse', 'COVID2019', 'COVID19', 'COVID', 'coronavirus', 'COVID19', 'marketresearch', 'consumerinsights', 'stopthespread', 'socialdistancing', 'COVID2019', 'Odisha', 'OdishaNews', 'OmmcomNews', 'ecommerce', 'retail', 'dtc', 'coronapocalypse', 'covid19', 'Covid19', 'coronaoutbreak', 'falsepanic', 'coronavirus', 'worldshutdown', 'coronavirus', 'applications', 'Coronavirus', 'coronavirus', 'coronavirus', 'NewZealand', 'CPTPP', 'coronavirus', 'COVID19', 'COVID2019', 'SupremeCourt', 'coronavirus', 'coronavirusoutbreaks', 'COVID2019', 'coronavirus', 'mealplan', 'mealprep', 'stockup', 'coronapocolypse', 'HowToKeepPeopleHome', 'Covid_19', 'schoolclosure', 'QuarantineLife', 'coronavirus', 'supplychainmanagement', 'smart', 'Kuwait', 'online', 'sites', 'coronavirus', 'thankingkuwaitcorona', 'Staythefuckhome', 'cinephile', 'stayhome', 'Covid_19', 'coronapocolypse', 'coronavirus', 'Babyboom2020', 'ecommerce', 'shoplocal', 'coronavirus', 'Coronavirus', 'COVID', 'consumers', 'food', 'drink', 'beauty', 'retail', 'health', 'COVID19', 'marketresearch', 'consumerinsights', 'consumerbehavior', 'trustedsource', 'COVID19', 'coronavirus', 'CoronaVirus', 'healthworkers', 'COVID19', 'coronavirus', 'affiliate', 'Coronavirus', 'COVID19', 'nycs', 'coronavirus', 'Covid_19', 'America', 'SickofWinning', 'coronavirus', 'coronavirus', 'COVID2019', 'covid19houston', 'COVID2019', 'COVID2019', 'Drive', 'coronavirus', 'coffee', 'COVID2019', 'ralphs', 'McDonaldsCoffee', 'GroceryStore', 'Covid_19', 'US', 'CoronaVirusSA', 'Coronavirussouthafrica', 'COVID2019', 'coronavirus', 'COVID2019', 'coronavirus', 'CoronavirusOutbreak', 'COVID2019', 'coronavirus', 'immigrantsong', 'COVID19', 'coronavirus', 'canadalockdown', 'coronavirus', 'COVID2019', 'COVID2019', 'coronavirus', 'panicbuying', 'GroceryStore', 'coronavirus', 'bringmeauntjemima', 'finalstraw', 'coronavirus', 'staysafe', 'stayhealthy', 'stockup', 'weareopen', 'corona', 'coronavirus', 'blissbakedgoods', 'coronavirus', 'LosAngeles', 'coronavirus', 'Corvid19uk', 'COVID2019', 'COVID19', 'coronavirus', 'health', 'COVID2019', 'coronavirus', 'CoronavirusOutbreak', 'nutrition', 'fintech', 'contactless', 'coronavirus', 'payment', 'paytech', 'lendtech', 'processing', 'ach', 'coronavirus', 'coronavirus', 'StPatricksDay', 'StayAtHomeChallenge', 'firstresponders', 'grocerystores', 'COVID2019', 'ChineseVirus', 'TuesdayMorning', 'dollargeneral', 'COVID2019', 'arthritis', 'COVID2019', 'coronavirus', 'Euro2020', 'COVID2019', 'transfermar ...

# %%
# making frequency distribution of top 10 Extremely Positive hashtags

import nltk # for text manipulation

a = nltk.FreqDist(HT_Extremely_Positive)
d = pd.DataFrame({'Hashtag': list(a.keys()),
                  'Count' : list(a.values())})

d = d.nlargest(columns = 'Count', n = 10)

plt.figure(figsize = (16,5))
ax = sns.barplot(data =d, x = 'Hashtag', y = 'Count')
plt.show()

# %%
# making frequency distribution top 10 Positive hashtags

a = nltk.FreqDist(HT_Positive)
d = pd.DataFrame({'Hashtag': list(a.keys()),
                  'Count' : list(a.values())})

d = d.nlargest(columns = 'Count', n = 10)

plt.figure(figsize = (16,5))
ax = sns.barplot(data =d, x = 'Hashtag', y = 'Count')
plt.show()

# %%
# making frequency distribution top 10 Neutral hashtags

a = nltk.FreqDist(HT_Neutral)
d = pd.DataFrame({'Hashtag': list(a.keys()),
                  'Count' : list(a.values())})

d = d.nlargest(columns = 'Count', n = 10)

plt.figure(figsize = (16,5))
ax = sns.barplot(data =d, x = 'Hashtag', y = 'Count')
plt.show()

# %%
# making frequency distribution top 10 Negative hashtags

a = nltk.FreqDist(HT_Negative)
d = pd.DataFrame({'Hashtag': list(a.keys()),
                  'Count' : list(a.values())})

d = d.nlargest(columns = 'Count', n = 10)

plt.figure(figsize = (16,5))
ax = sns.barplot(data =d, x = 'Hashtag', y = 'Count')
plt.show()

# %%
# making frequency distribution top 10 Extremely Negative hashtags

a = nltk.FreqDist(HT_Extremely_Negative)
d = pd.DataFrame({'Hashtag': list(a.keys()),
                  'Count' : list(a.values())})

d = d.nlargest(columns = 'Count', n = 10)

plt.figure(figsize = (16,5))
ax = sns.barplot(data =d, x = 'Hashtag', y = 'Count')
plt.show()

# %% [markdown]
# ##Extracting Features from Cleaned Tweets

# %%
new_df = df[['Tweet','Sentiment']]

# %%
new_df.head()
# Out:
#                                                Tweet           Sentiment
# 0                                                                Neutral
# 1  advice Talk your neighbours family exchange ph...            Positive
# 2  Coronavirus Australia Woolworths give elderly ...            Positive
# 3  food stock not the only one which empty PLEASE...            Positive
# 4  ready supermarket during the #COVID outbreak N...  Extremely Negative

# %%
df['Sentiment'].value_counts()
# Out:
# Positive              11422
# Negative               9917
# Neutral                7713
# Extremely Positive     6624
# Extremely Negative     5481
# Name: Sentiment, dtype: int64

# %% [markdown]
# Converting into lower case

# %%
#new_df["Tweet"] = new_df["Tweet"].str.lower().str.split()

# %%
#new_df.head(5)

# %% [markdown]
# Removing Stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
new_df['Tweet'].apply(lambda x: [item for item in x if item not in stop])
# Out:
# 0                                                       []
# 1        [v, c, e,  , T, l, k,  , u, r,  , n, e, g, h, ...
# 2        [C, r, n, v, r, u,  , A, u, r, l,  , W, l, w, ...
# 3        [f,  , c, k,  , n,  , h, e,  , n, l,  , n, e, ...
# 4        [r, e,  , u, p, e, r, r, k, e,  , u, r, n, g, ...
#                                ...
# 41152    [A, r, l, n, e,  , p, l,  , f, f, e, r, n, g, ...
# 41153    [R, e, p, n, e,  , c, p, l, n,  , n,  , p, r, ...
# 41154    [Y, u,  , k, n, w,  , g, e, n, g,  , u, g, h, ...
# 41155    [w, r, n, g,  , h,  , h, e,  , e, l, l,  , h, ...
# 41156    [W, e, l, l,  , n, e, w,  , u, e,  , R, f,  , ...
# Name: Tweet, Length: 41157, dtype: object

# %%
new_df.head(6)
# Out:
#                                                Tweet           Sentiment
# 0                                                                Neutral
# 1  advice Talk your neighbours family exchange ph...            Positive
# 2  Coronavirus Australia Woolworths give elderly ...            Positive
# 3  food stock not the only one which empty PLEASE...            Positive
# 4  ready supermarket during the #COVID outbreak N...  Extremely Negative
# 5  news the region first confirmed COVID case cam...            Positive

# %%
new_df.shape
# Out:
# (41157, 2)

# %%
new_df.isnull().sum()
# Out:
# Tweet        0
# Sentiment    0
# dtype: int64

# %%
new_df.head(7)
# Out:
#                                                Tweet           Sentiment
# 0                                                                Neutral
# 1  advice Talk your neighbours family exchange ph...            Positive
# 2  Coronavirus Australia Woolworths give elderly ...            Positive
# 3  food stock not the only one which empty PLEASE...            Positive
# 4  ready supermarket during the #COVID outbreak N...  Extremely Negative
# 5  news the region first confirmed COVID case cam...            Positive
# 6  Cashier grocery store was sharing his insights...            Positive
